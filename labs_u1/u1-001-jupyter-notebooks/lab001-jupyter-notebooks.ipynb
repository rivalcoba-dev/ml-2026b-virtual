# %% [markdown]
# # 🧪 Lab: Breve introducción a Python y los cuadernos de Jupyter
# ## Objetivos
# En este laboratorio:
# - Obtendrás una breve introducción a los cuadernos de Jupyter
# - Harás un recorrido por los cuadernos de Jupyter
# - Aprenderás la diferencia entre las celdas Markdown y las celdas de código
# - Practicarás algunos conceptos básicos de Python

# %% [markdown]
# La mejor forma de familiarizarte con los Jupyter Notebooks en **VsCode** es leer la documentación [aqui](https://code.visualstudio.com/docs/datascience/jupyter-notebooks)

# %% [markdown]
# En los Jupyter notebooks hay dos tipos de celdas, celdas como esta que solo contienen documentación llamadas `Markdown Cells`. El nombre proviene de un lenguaje de marcado llamado `markdown`.

# %% [markdown]
# # Titulo 1
#
# Esto es un texto **asombroso** o __amazing__.
#
# $$
# \frac{1}{2}+1\frac{\beta}{x^{\alpha}}
# $$

# %% [markdown]
#  El otro tipo de celdas son las `Code Cells` que sirven para ingresar código en Python 🐍.

# %%
# This is  a 'Code' Cell
print("Esta es una celda 🐞")
print("Esto es Python 🎡")

# for iteration in range(1,15):
#     print("⭐ Esto es un mensaje repetido ⭐"," ",iteration)

# %% [markdown]
# ## Python
#
# Tu puedes escribir código en las `code cells`. Para ejecutar el código de la celda, selecciona una celda y mientras mantienen presionado el botón _Shift_ presiona _enter_.
#
# Intenta con la celda de arriba 👆

# %% [markdown]
# ### Sentencia Print
# La sentencia `print()` generalmente usara el estilo `f-string`
# A continuación te presento un ejemplo:

# %% [markdown]
# ```python
# variable = 100
# print("Esto es un mensaje")
# ```
#
# * Esto es una Viñeta
# * Esto es otra viñeta
#
# 1. Hola
# 2. Adios
# 3. Hart
#
# > Esto es una quote o una cita -- John Doe

# %%
# print statements
variable_A1 = 100
result = variable_A1 * 2
print(f"El resultado de {variable_A1} * 200 es {result}")

# %% [markdown]
# # 🎉 Felicidades!
# Ya sabes lo básico de Jupyter Notebooks!!!
